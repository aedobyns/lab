# %%
import numpy as np
import scipy
from scipy import signal
import matplotlib.pyplot as plt
import sys

# %%
from numpy import NaN, Inf, arange, isscalar, asarray, array
 
def peakdet(v, delta, x = None):
    """
    Converted from MATLAB script at http://billauer.co.il/peakdet.html
    
    Returns two arrays
    
    function [maxtab, mintab]=peakdet(v, delta, x)
    # %PEAKDET Detect peaks in a vector
    %        [MAXTAB, MINTAB] = PEAKDET(V, DELTA) finds the local
    %        maxima and minima ("peaks") in the vector V.
    %        MAXTAB and MINTAB consists of two columns. Column 1
    %        contains indices in V, and column 2 the found values.
    %      
    %        With [MAXTAB, MINTAB] = PEAKDET(V, DELTA, X) the indices
    %        in MAXTAB and MINTAB are replaced with the corresponding
    %        X-values.
    %
    %        A point is considered a maximum peak if it has the maximal
    %        value, and was preceded (to the left) by a value lower by
    %        DELTA.
    
    % Eli Billauer, 3.4.05 (Explicitly not copyrighted).
    % This function is released to the public domain; Any use is allowed.
    
    """
    maxtab = []
    mintab = []
       
    if x is None:
        x = arange(len(v))
    
    v = asarray(v)
    
    if len(v) != len(x):
        sys.exit('Input vectors v and x must have same length')
    
    if not isscalar(delta):
        sys.exit('Input argument delta must be a scalar')
    
    if delta <= 0:
        sys.exit('Input argument delta must be positive')
    
    mn, mx = Inf, -Inf
    mnpos, mxpos = NaN, NaN
    
    lookformax = True
    
    for i in arange(len(v)):
        this = v[i]
        if this > mx:
            mx = this
            mxpos = x[i]
        if this < mn:
            mn = this
            mnpos = x[i]
        
        if lookformax:
            if this < mx-delta:
                maxtab.append((mxpos, mx))
                mn = this
                mnpos = x[i]
                lookformax = False
        else:
            if this > mn+delta:
                mintab.append((mnpos, mn))
                mx = this
                mxpos = x[i]
                lookformax = True
 
    return array(maxtab), array(mintab)

# %%
from matplotlib import cbook

class DataCursor(object):
    """A simple data cursor widget that displays the x,y location of a
    matplotlib artist when it is selected."""
    def __init__(self, artists, tolerance=5, offsets=(-20, 20), 
                 template='x: %0.2f\ny: %0.2f', display_all=False):
        """Create the data cursor and connect it to the relevant figure.
        "artists" is the matplotlib artist or sequence of artists that will be 
            selected. 
        "tolerance" is the radius (in points) that the mouse click must be
            within to select the artist.
        "offsets" is a tuple of (x,y) offsets in points from the selected
            point to the displayed annotation box
        "template" is the format string to be used. Note: For compatibility
            with older versions of python, this uses the old-style (%) 
            formatting specification.
        "display_all" controls whether more than one annotation box will
            be shown if there are multiple axes.  Only one will be shown
            per-axis, regardless. 
        """
        self.template = template
        self.offsets = offsets
        self.display_all = display_all
        if not cbook.iterable(artists):
            artists = [artists]
        self.artists = artists
        self.axes = tuple(set(art.axes for art in self.artists))
        self.figures = tuple(set(ax.figure for ax in self.axes))

        self.annotations = {}
        for ax in self.axes:
            self.annotations[ax] = self.annotate(ax)

        for artist in self.artists:
            artist.set_picker(tolerance)
        for fig in self.figures:
            fig.canvas.mpl_connect('pick_event', self)

    def annotate(self, ax):
        """Draws and hides the annotation box for the given axis "ax"."""
        annotation = ax.annotate(self.template, xy=(0, 0), ha='right',
                xytext=self.offsets, textcoords='offset points', va='bottom',
                bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
                arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0')
                )
        annotation.set_visible(False)
        return annotation

    def __call__(self, event):
        """Intended to be called through "mpl_connect"."""
        # Rather than trying to interpolate, just display the clicked coords
        # This will only be called if it's within "tolerance", anyway.
        x, y = event.mouseevent.xdata, event.mouseevent.ydata
        annotation = self.annotations[event.artist.axes]
        if x is not None:
            if not self.display_all:
                # Hide any other annotation boxes...
                for ann in self.annotations.values():
                    ann.set_visible(False)
            # Update the annotation in the current axis..
            annotation.xy = x, y
            annotation.set_text(self.template % (x, y))
            annotation.set_visible(True)
            event.canvas.draw()

#if __name__ == '__main__':
    #import matplotlib.pyplot as plt
    #plt.figure()
    #plt.subplot(2,1,1)
    #line1, = plt.plot(range(10), 'ro-')
    #plt.subplot(2,1,2)
    #line2, = plt.plot(range(10), 'bo-')

    #DataCursor([line1, line2])

# %%
def baseline(data,rate):
    #input data array and rate value.
    #using the first 0.1 s of data, find average of all data values. this becomes the baseline.
    #baseline is used later in burst measurements
    #import numpy as np
    
    index = 0.2/rate
    baserate = np.mean(data[:index])
    
    datashift = []
    
    #may be able to use np.subtract(data,base) instead, but this seems to work correctly.
    for x in data:
        foo = (x-baserate)
        datashift.append(foo)
        
    return baserate, datashift

# %%
def burstduration(time, data, baserate, threshperc=0.2, clusterperc=0.006):
    #threshperc should be 0<= x <= 1
    #baserate needs to be calculated and passed into this argument
    #data should already be transformed, smoothed, and baseline shifted
    
    if len(time) != len(data): #logic check, are the number of data points and time points the same?
        sys.exit('You cannot have more time points than there are data points. Get that sorted, buddy.')    
    
    burst_start = [] #empty array for burst start
    burst_end = [] #empty array for burst end
    burst_duration = [] #empty array to calculate burst durration
    
    threshold = baserate * threshperc #calculate the point at which a event is considered a peak
    
    burst = False #burst flag, should start not in a burst

    for point in data: #for each data point in the set
        
        timeindex = data.index(point) #find the time index of a given data point
        tpoint = time[timeindex] #find the actual time given teh time index
        
        if burst == False and point > threshold: #if we are not in a burst already, the value is higher than the threshold, AND the last burst didn't end less than .2 ms ago
            burst_start.append(tpoint) #add the time at point as the begining of the burst
            burst = True #burst flag, we are now in a burst 
        
        if burst == True and  point <= threshold: #if we are in a burst and the point falls below the threshold
            
            if len(burst_end) == 0 or len(burst_start) == 0: #if this is the first end
                burst_end.append (tpoint) #add the time at point as the end of the burst
                burst = False #burst flag, we are now out of the burst
    
            #elif burst_start[-1] > (burst_end[-1] + 0.0007): #if the start time and the last end time are too close together, don't add it as a seperate burst
            #    del burst_end[-1] #delete the last end time
             #   burst_end.append(tpoint) #replace it with the new end time
              #  del burst_start[-1] #get rid of new start time, since it isn't really a new start time
            
            else:
                burst_end.append (tpoint) #add the time at point as the end of the burst
                burst = False #burst flag, we are now out of the burst
                if burst_start[-1] < (burst_end[-2] + clusterperc):
                    del burst_end[-2]
                    del burst_start[-1]
    
    #if len(burst_start) != len(burst_end):
        #sys.exit('Unexpectedly, the number of burst start times and end times are not equal. Seeing as this is physically impossible, I quit the program for you. Begin hunting for the fatal flaw. Good luck!')
        
    
    for foo in burst_start: #for each burst
        index = burst_start.index(foo)
        duration = burst_end[index] - burst_start[index] #calculate duration by subtracting the start time from the end time, found by indexing
        burst_duration.append(duration) #add the burst duration to the duration list
    
    return burst_start, burst_end, burst_duration

# %%
def ibi(burst_start, burst_end):
    """
    this function is used to find the inter-burst interval. 
    this is defined as the difference between the last end and the new start time
    Dependent on numpy, burst_start, and burst_end
    """
    
    ibi = []
    
    for end in burst_end[:-1]: #for each end time except the last one
        tindex = burst_end.index(end) #find the start time index
        start = burst_start[tindex+1] #find start time
        ibi.append(start-end) #subtract the old end time from the start time
    
    return ibi

# %%
def ttot(burst_start): #find time from start to start
    
    ttotal = [] #empty array for ttot to go into
    
    for time in burst_start[1:]: #for each start time, starting with the second one
        s2time = burst_start.index(time)
        s2 = burst_start[s2time-1]
        meas = time - s2 #measure the interval by subtracting
        ttotal.append(meas) #append the measurement to the ttotal array
    return ttotal #return array

# %%
def burstpeaks(data, burst_start, burst_end, time=0, delta=0.04):
    """
    given the burst start and end time, along with the looser peak detect, calculate the number of peaks in a given burst
    dependent on burstduration, numpy, sys, and peakdet
    default delta is 0.04, based on ECG data, seems to catch QRS and sometimes P and/or T
    data MUST be transformed, but not shifted. peakdet will reject it if it has negative values
    time varible is the value of time at the the first index of the time array. You can input it in as time=TIME_ARRAY[0]
    """
    
    if len(burst_start) != len(burst_end): #logic check, before we start
        sys.exit('Unexpectedly, the number of burst start times and end times are not equal. Seeing as this is physically impossible, I quit the program for you. Begin hunting for the fatal flaw. Good luck!')
    
    if (len(burst_start) == 0) or (len(burst_end) == 0): #logic check, are they empty lists
        sys.exit('One of the imput arrays is an empty list')
    maxtab, mintab= peakdet(data, delta) #generate the maxtab array of times and heights
    
    maxptime = maxtab[:,0]
    maxptime = (np.multiply(maxptime,0.00025) + time)
    
    index = 0 #initalize burst index to zero
    burst = False #initalize burst status to False
    burstpeaknum = [] #empty array for where the number of peaks will go. index # = burst #
    burstpeaks = [] #empty tuple of peak locations. index # = burst #
    
    for time in maxptime: #for each peak found in maxtab. remember that maxtab has multipule columns, so only take time.
        
        if (index<=(len(burst_start)-1)) and burst == False: #if not in a burst
            
            if (burst_start[index] < time): #look for first peak inside burst
                plist = [] #empty list of all peaks
                burst = True
                print "burst flag is now True at index=", index, "and max p time=", time
                
        if (index<=(len(burst_start)-1)) and burst == True: #if in a burst
            
            if burst_end[index] < time: #if the next peak is outside the bust
                burstpeaks.append(plist) #put list of peaks in burst peaks list
                burstpeaknum.append(len(plist)) #add count of peaks to burst peak num list
                burst = False #reset burst flag, since we are now out of burst
                print "at index=", index, ",", len(plist), "peaks were added"
                print "burst flag is now False"
                index = (index+1)
                
                
            if burst_end[index] > time and burst == True: #is the peak inside the burst
                plist.append(time)#add time to list of peak times
                print "at index=", index, "," , time, "was appended to plist"
            
           
    return burstpeaknum, burstpeaks, maxtab

# %%
def savitzky_golay(y, window_size, order, deriv=0, rate=1):
    r"""Smooth (and optionally differentiate) data with a Savitzky-Golay filter.
    The Savitzky-Golay filter removes high frequency noise from data.
    It has the advantage of preserving the original shape and
    features of the signal better than other types of filtering
    approaches, such as moving averages techniques.
    Parameters
    ----------
    y : array_like, shape (N,)
        the values of the time history of the signal.
    window_size : int
        the length of the window. Must be an odd integer number.
    order : int
        the order of the polynomial used in the filtering.
        Must be less then `window_size` - 1.
    deriv: int
        the order of the derivative to compute (default = 0 means only smoothing)
    Returns
    -------
    ys : ndarray, shape (N)
        the smoothed signal (or it's n-th derivative).
    Notes
    -----
    The Savitzky-Golay is a type of low-pass filter, particularly
    suited for smoothing noisy data. The main idea behind this
    approach is to make for each point a least-square fit with a
    polynomial of high order over a odd-sized window centered at
    the point.
    Examples
    --------
    t = np.linspace(-4, 4, 500)
    y = np.exp( -t**2 ) + np.random.normal(0, 0.05, t.shape)
    ysg = savitzky_golay(y, window_size=31, order=4)
    import matplotlib.pyplot as plt
    plt.plot(t, y, label='Noisy signal')
    plt.plot(t, np.exp(-t**2), 'k', lw=1.5, label='Original signal')
    plt.plot(t, ysg, 'r', label='Filtered signal')
    plt.legend()
    plt.show()
    References
    ----------
    .. [1] A. Savitzky, M. J. E. Golay, Smoothing and Differentiation of
       Data by Simplified Least Squares Procedures. Analytical
       Chemistry, 1964, 36 (8), pp 1627-1639.
    .. [2] Numerical Recipes 3rd Edition: The Art of Scientific Computing
       W.H. Press, S.A. Teukolsky, W.T. Vetterling, B.P. Flannery
       Cambridge University Press ISBN-13: 9780521880688
    """
    import numpy as np
    from math import factorial

    try:
        window_size = np.abs(np.int(window_size))
        order = np.abs(np.int(order))
    except ValueError, msg:
        raise ValueError("window_size and order have to be of type int")
    if window_size % 2 != 1 or window_size < 1:
        raise TypeError("window_size size must be a positive odd number")
    if window_size < order + 2:
        raise TypeError("window_size is too small for the polynomials order")
    order_range = range(order+1)
    half_window = (window_size -1) // 2
    # precompute coefficients
    b = np.mat([[k**i for i in order_range] for k in range(-half_window, half_window+1)])
    m = np.linalg.pinv(b).A[deriv] * rate**deriv * factorial(deriv)
    # pad the signal at the extremes with
    # values taken from the signal itself
    firstvals = y[0] - np.abs( y[1:half_window+1][::-1] - y[0] )
    lastvals = y[-1] + np.abs(y[-half_window-1:-1][::-1] - y[-1])
    y = np.concatenate((firstvals, y, lastvals))
    return np.convolve( m[::-1], y, mode='valid')

# %% [markdown]
# end functions
# begin user input

# %%
time, data = np.loadtxt("/Users/abigaildobyns/Dropbox/Wilson_lab_papers/Abby/data/2014-29-04rat56-ECG.txt", delimiter="\t", usecols=(0,1),  unpack=True)
widths = np.loadtxt("/Users/abigaildobyns/Dropbox/Wilson_lab_papers/Abby/data/widths.txt", delimiter= "\t", unpack=True)
time = time[1800:]
data = data[1800:]

# %%
data_trans = abs(data)
data_trans =savitzky_golay(data_trans, 47, 4)

# %%
base, data_shift =baseline(data_trans,0.00025)

# %% [markdown]
# peakdet **CANNOT** take negative values, so base_shift cannot be used to calculate the peaks.

# %%
maxtab, mintab = peakdet(data_trans, 0.6, None)

# %%
maxtab = np.array(maxtab)
maxptime = maxtab[:,0]
maxptime = (np.multiply(maxptime,0.00025) + time[0])
maxpeaks = maxtab[:,1]
maxpeaks = (np.subtract(maxpeaks,base))

# %% [markdown]
# mintab = np.array(mintab)
# minptime = mintab[:,0]
# minptime = (np.multiply(minptime,0.00025) + time[0])
# minpeaks = mintab[:,1]

# %%
bstart, bend, bdur = burstduration(time, data_shift, base, threshperc=0.5)

# %%
len(bend) == len(bstart)
# Out:
# True

# %%
print len(bend)
print len(bstart)
# Out:
# 111
# 111

# %%
x = ibi(bstart, bend)
print len(x)
# Out:
# 110

# %%
tot = ttot(bstart)
print len(tot)
# Out:
# 110

# %%
x[:5]
# Out:
# [0.1705000000000001,
#  0.17649999999999988,
#  0.1692499999999999,
#  0.0064999999999999503,
#  0.17599999999999993]

# %%
burstpeak_num, burstpeaks, maxtabALL = burstpeaks(data_trans, bstart, bend, time=time[0])
# Out:
# burst flag is now True at index= 0 and max p time= 1.04075
# at index= 0 , 1.04075 was appended to plist
# at index= 0 , 1.051 was appended to plist
# at index= 0 , 1.05975 was appended to plist
# at index= 0 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 1 and max p time= 1.241
# at index= 1 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 2 and max p time= 1.251
# at index= 2 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 3 and max p time= 1.26125
# at index= 3 , 1.26125 was appended to plist
# at index= 3 , 1.27025 was appended to plist
# at index= 3 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 4 and max p time= 1.29
# at index= 4 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 5 and max p time= 1.4605
# at index= 5 , 1.4605 was appended to plist
# at index= 5 , 1.47075 was appended to plist
# at index= 5 , 1.47925 was appended to plist
# at index= 5 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 6 and max p time= 1.65875
# at index= 6 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 7 and max p time= 1.66925
# at index= 7 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 8 and max p time= 1.68
# at index= 8 , 1.68 was appended to plist
# at index= 8 , 1.6885 was appended to plist
# at index= 8 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 9 and max p time= 1.70775
# at index= 9 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 10 and max p time= 1.8785
# at index= 10 , 1.8785 was appended to plist
# at index= 10 , 1.88875 was appended to plist
# at index= 10 , 1.897 was appended to plist
# at index= 10 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 11 and max p time= 2.08675
# at index= 11 , 2.08675 was appended to plist
# at index= 11 , 2.0975 was appended to plist
# at index= 11 , 2.106 was appended to plist
# at index= 11 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 12 and max p time= 2.12475
# at index= 12 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 13 and max p time= 2.2955
# at index= 13 , 2.2955 was appended to plist
# at index= 13 , 2.3055 was appended to plist
# at index= 13 , 2.314 was appended to plist
# at index= 13 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 14 and max p time= 2.5035
# at index= 14 , 2.5035 was appended to plist
# at index= 14 , 2.51425 was appended to plist
# at index= 14 , 2.52275 was appended to plist
# at index= 14 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 15 and max p time= 2.71225
# at index= 15 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 16 and max p time= 2.72225
# at index= 16 , 2.72225 was appended to plist
# at index= 16 , 2.731 was appended to plist
# at index= 16 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 17 and max p time= 2.92175
# at index= 17 , 2.92175 was appended to plist
# at index= 17 , 2.93225 was appended to plist
# at index= 17 , 2.941 was appended to plist
# at index= 17 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 18 and max p time= 3.131
# at index= 18 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 19 and max p time= 3.141
# at index= 19 , 3.141 was appended to plist
# at index= 19 , 3.14975 was appended to plist
# at index= 19 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 20 and max p time= 3.339
# at index= 20 , 3.339 was appended to plist
# at index= 20 , 3.35 was appended to plist
# at index= 20 , 3.35825 was appended to plist
# at index= 20 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 21 and max p time= 3.53775
# at index= 21 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 22 and max p time= 3.54725
# at index= 22 , 3.54725 was appended to plist
# at index= 22 , 3.55725 was appended to plist
# at index= 22 , 3.566 was appended to plist
# at index= 22 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 23 and max p time= 3.75475
# at index= 23 , 3.75475 was appended to plist
# at index= 23 , 3.76575 was appended to plist
# at index= 23 , 3.774 was appended to plist
# at index= 23 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 24 and max p time= 3.79225
# at index= 24 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 25 and max p time= 3.9635
# at index= 25 , 3.9635 was appended to plist
# at index= 25 , 3.9735 was appended to plist
# at index= 25 , 3.982 was appended to plist
# at index= 25 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 26 and max p time= 4.171
# at index= 26 , 4.171 was appended to plist
# at index= 26 , 4.18175 was appended to plist
# at index= 26 , 4.19025 was appended to plist
# at index= 26 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 27 and max p time= 4.3795
# at index= 27 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 28 and max p time= 4.389
# at index= 28 , 4.389 was appended to plist
# at index= 28 , 4.398 was appended to plist
# at index= 28 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 29 and max p time= 4.587
# at index= 29 , 4.587 was appended to plist
# at index= 29 , 4.5975 was appended to plist
# at index= 29 , 4.60625 was appended to plist
# at index= 29 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 30 and max p time= 4.7955
# at index= 30 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 31 and max p time= 4.8055
# at index= 31 , 4.8055 was appended to plist
# at index= 31 , 4.814 was appended to plist
# at index= 31 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 32 and max p time= 5.0025
# at index= 32 , 5.0025 was appended to plist
# at index= 32 , 5.01325 was appended to plist
# at index= 32 , 5.02175 was appended to plist
# at index= 32 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 33 and max p time= 5.21025
# at index= 33 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 34 and max p time= 5.2205
# at index= 34 , 5.2205 was appended to plist
# at index= 34 , 5.22875 was appended to plist
# at index= 34 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 35 and max p time= 5.40725
# at index= 35 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 36 and max p time= 5.417
# at index= 36 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 37 and max p time= 5.4275
# at index= 37 , 5.4275 was appended to plist
# at index= 37 , 5.4365 was appended to plist
# at index= 37 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 38 and max p time= 5.4565
# at index= 38 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 39 and max p time= 5.62425
# at index= 39 , 5.62425 was appended to plist
# at index= 39 , 5.635 was appended to plist
# at index= 39 , 5.64325 was appended to plist
# at index= 39 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 40 and max p time= 5.8225
# at index= 40 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 41 and max p time= 5.8315
# at index= 41 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 42 and max p time= 5.84175
# at index= 42 , 5.84175 was appended to plist
# at index= 42 , 5.8505 was appended to plist
# at index= 42 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 43 and max p time= 6.0385
# at index= 43 , 6.0385 was appended to plist
# at index= 43 , 6.04875 was appended to plist
# at index= 43 , 6.05775 was appended to plist
# at index= 43 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 44 and max p time= 6.237
# at index= 44 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 45 and max p time= 6.24625
# at index= 45 , 6.24625 was appended to plist
# at index= 45 , 6.25625 was appended to plist
# at index= 45 , 6.265 was appended to plist
# at index= 45 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 46 and max p time= 6.453
# at index= 46 , 6.453 was appended to plist
# at index= 46 , 6.46375 was appended to plist
# at index= 46 , 6.47225 was appended to plist
# at index= 46 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 47 and max p time= 6.49125
# at index= 47 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 48 and max p time= 6.6605
# at index= 48 , 6.6605 was appended to plist
# at index= 48 , 6.6705 was appended to plist
# at index= 48 , 6.67875 was appended to plist
# at index= 48 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 49 and max p time= 6.857
# at index= 49 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 50 and max p time= 6.86675
# at index= 50 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 51 and max p time= 6.87725
# at index= 51 , 6.87725 was appended to plist
# at index= 51 , 6.88575 was appended to plist
# at index= 51 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 52 and max p time= 7.0735
# at index= 52 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 53 and max p time= 7.08425
# at index= 53 , 7.08425 was appended to plist
# at index= 53 , 7.09225 was appended to plist
# at index= 53 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 54 and max p time= 7.28
# at index= 54 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 55 and max p time= 7.29
# at index= 55 , 7.29 was appended to plist
# at index= 55 , 7.29875 was appended to plist
# at index= 55 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 56 and max p time= 7.48575
# at index= 56 , 7.48575 was appended to plist
# at index= 56 , 7.4965 was appended to plist
# at index= 56 , 7.50525 was appended to plist
# at index= 56 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 57 and max p time= 7.69225
# at index= 57 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 58 and max p time= 7.70225
# at index= 58 , 7.70225 was appended to plist
# at index= 58 , 7.711 was appended to plist
# at index= 58 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 59 and max p time= 7.8895
# at index= 59 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 60 and max p time= 7.89925
# at index= 60 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 61 and max p time= 7.90925
# at index= 61 , 7.90925 was appended to plist
# at index= 61 , 7.91825 was appended to plist
# at index= 61 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 62 and max p time= 8.09475
# at index= 62 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 63 and max p time= 8.1055
# at index= 63 , 8.1055 was appended to plist
# at index= 63 , 8.11625 was appended to plist
# at index= 63 , 8.12475 was appended to plist
# at index= 63 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 64 and max p time= 8.312
# at index= 64 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 65 and max p time= 8.322
# at index= 65 , 8.322 was appended to plist
# at index= 65 , 8.33075 was appended to plist
# at index= 65 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 66 and max p time= 8.5175
# at index= 66 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 67 and max p time= 8.52825
# at index= 67 , 8.52825 was appended to plist
# at index= 67 , 8.537 was appended to plist
# at index= 67 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 68 and max p time= 8.55625
# at index= 68 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 69 and max p time= 8.72375
# at index= 69 , 8.72375 was appended to plist
# at index= 69 , 8.73425 was appended to plist
# at index= 69 , 8.7425 was appended to plist
# at index= 69 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 70 and max p time= 8.9295
# at index= 70 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 71 and max p time= 8.93975
# at index= 71 , 8.93975 was appended to plist
# at index= 71 , 8.94825 was appended to plist
# at index= 71 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 72 and max p time= 9.135
# at index= 72 , 9.135 was appended to plist
# at index= 72 , 9.1455 was appended to plist
# at index= 72 , 9.1545 was appended to plist
# at index= 72 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 73 and max p time= 9.34225
# at index= 73 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 74 and max p time= 9.352
# at index= 74 , 9.352 was appended to plist
# at index= 74 , 9.36075 was appended to plist
# at index= 74 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 75 and max p time= 9.53875
# at index= 75 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 76 and max p time= 9.54825
# at index= 76 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 77 and max p time= 9.5585
# at index= 77 , 9.5585 was appended to plist
# at index= 77 , 9.56725 was appended to plist
# at index= 77 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 78 and max p time= 9.743
# at index= 78 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 79 and max p time= 9.754
# at index= 79 , 9.754 was appended to plist
# at index= 79 , 9.76475 was appended to plist
# at index= 79 , 9.77325 was appended to plist
# at index= 79 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 80 and max p time= 9.9605
# at index= 80 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 81 and max p time= 9.9705
# at index= 81 , 9.9705 was appended to plist
# at index= 81 , 9.97875 was appended to plist
# at index= 81 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 82 and max p time= 10.15625
# at index= 82 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 83 and max p time= 10.166
# at index= 83 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 84 and max p time= 10.1765
# at index= 84 , 10.1765 was appended to plist
# at index= 84 , 10.18525 was appended to plist
# at index= 84 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 85 and max p time= 10.3605
# at index= 85 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 86 and max p time= 10.37175
# at index= 86 , 10.37175 was appended to plist
# at index= 86 , 10.3825 was appended to plist
# at index= 86 , 10.39075 was appended to plist
# at index= 86 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 87 and max p time= 10.56825
# at index= 87 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 88 and max p time= 10.57775
# at index= 88 , 10.57775 was appended to plist
# at index= 88 , 10.58775 was appended to plist
# at index= 88 , 10.59625 was appended to plist
# at index= 88 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 89 and max p time= 10.7735
# at index= 89 , 10.7735 was appended to plist
# at index= 89 , 1 peaks were added
# burst flag is now False
# burst flag is now True at index= 90 and max p time= 10.79325
# at index= 90 , 10.79325 was appended to plist
# at index= 90 , 10.8025 was appended to plist
# at index= 90 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 91 and max p time= 10.98925
# at index= 91 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 92 and max p time= 10.9995
# at index= 92 , 10.9995 was appended to plist
# at index= 92 , 11.00825 was appended to plist
# at index= 92 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 93 and max p time= 11.18625
# at index= 93 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 94 and max p time= 11.1955
# at index= 94 , 11.1955 was appended to plist
# at index= 94 , 11.2055 was appended to plist
# at index= 94 , 11.21425 was appended to plist
# at index= 94 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 95 and max p time= 11.40075
# at index= 95 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 96 and max p time= 11.41125
# at index= 96 , 11.41125 was appended to plist
# at index= 96 , 11.42025 was appended to plist
# at index= 96 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 97 and max p time= 11.6065
# at index= 97 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 98 and max p time= 11.617
# at index= 98 , 11.617 was appended to plist
# at index= 98 , 11.6255 was appended to plist
# at index= 98 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 99 and max p time= 11.8025
# at index= 99 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 100 and max p time= 11.812
# at index= 100 , 11.812 was appended to plist
# at index= 100 , 11.82225 was appended to plist
# at index= 100 , 11.83075 was appended to plist
# at index= 100 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 101 and max p time= 12.017
# at index= 101 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 102 and max p time= 12.02775
# at index= 102 , 12.02775 was appended to plist
# at index= 102 , 12.0365 was appended to plist
# at index= 102 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 103 and max p time= 12.22225
# at index= 103 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 104 and max p time= 12.23275
# at index= 104 , 12.23275 was appended to plist
# at index= 104 , 12.24125 was appended to plist
# at index= 104 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 105 and max p time= 12.4275
# at index= 105 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 106 and max p time= 12.437
# at index= 106 , 12.437 was appended to plist
# at index= 106 , 12.446 was appended to plist
# at index= 106 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 107 and max p time= 12.6235
# at index= 107 , 12.6235 was appended to plist
# at index= 107 , 1 peaks were added
# burst flag is now False
# burst flag is now True at index= 108 and max p time= 12.644
# at index= 108 , 12.644 was appended to plist
# at index= 108 , 12.653 was appended to plist
# at index= 108 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 109 and max p time= 12.6725
# at index= 109 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 110 and max p time= 12.839
# at index= 110 , 12.839 was appended to plist
# at index= 110 , 12.8495 was appended to plist
# at index= 110 , 12.858 was appended to plist
# at index= 110 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 111 and max p time= 13.0445
# at index= 111 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 112 and max p time= 13.0545
# at index= 112 , 13.0545 was appended to plist
# at index= 112 , 13.063 was appended to plist
# at index= 112 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 113 and max p time= 13.23925
# at index= 113 , 13.23925 was appended to plist
# at index= 113 , 1 peaks were added
# burst flag is now False
# burst flag is now True at index= 114 and max p time= 13.2595
# at index= 114 , 13.2595 was appended to plist
# at index= 114 , 13.26825 was appended to plist
# at index= 114 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 115 and max p time= 13.2885
# at index= 115 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 116 and max p time= 13.45375
# at index= 116 , 13.45375 was appended to plist
# at index= 116 , 13.46475 was appended to plist
# at index= 116 , 13.473 was appended to plist
# at index= 116 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 117 and max p time= 13.65875
# at index= 117 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 118 and max p time= 13.669
# at index= 118 , 13.669 was appended to plist
# at index= 118 , 13.67725 was appended to plist
# at index= 118 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 119 and max p time= 13.85375
# at index= 119 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 120 and max p time= 13.863
# at index= 120 , 13.863 was appended to plist
# at index= 120 , 13.87325 was appended to plist
# at index= 120 , 13.882 was appended to plist
# at index= 120 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 121 and max p time= 14.067
# at index= 121 , 14.067 was appended to plist
# at index= 121 , 14.0775 was appended to plist
# at index= 121 , 14.087 was appended to plist
# at index= 121 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 122 and max p time= 14.27325
# at index= 122 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 123 and max p time= 14.2835
# at index= 123 , 14.2835 was appended to plist
# at index= 123 , 14.292 was appended to plist
# at index= 123 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 124 and max p time= 14.4785
# at index= 124 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 125 and max p time= 14.4885
# at index= 125 , 14.4885 was appended to plist
# at index= 125 , 14.49725 was appended to plist
# at index= 125 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 126 and max p time= 14.673
# at index= 126 , 14.673 was appended to plist
# at index= 126 , 1 peaks were added
# burst flag is now False
# burst flag is now True at index= 127 and max p time= 14.6935
# at index= 127 , 14.6935 was appended to plist
# at index= 127 , 14.70225 was appended to plist
# at index= 127 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 128 and max p time= 14.8875
# at index= 128 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 129 and max p time= 14.89825
# at index= 129 , 14.89825 was appended to plist
# at index= 129 , 14.9065 was appended to plist
# at index= 129 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 130 and max p time= 15.09225
# at index= 130 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 131 and max p time= 15.10225
# at index= 131 , 15.10225 was appended to plist
# at index= 131 , 15.11075 was appended to plist
# at index= 131 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 132 and max p time= 15.28725
# at index= 132 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 133 and max p time= 15.2965
# at index= 133 , 15.2965 was appended to plist
# at index= 133 , 15.30675 was appended to plist
# at index= 133 , 15.31525 was appended to plist
# at index= 133 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 134 and max p time= 15.49075
# at index= 134 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 135 and max p time= 15.5005
# at index= 135 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 136 and max p time= 15.511
# at index= 136 , 15.511 was appended to plist
# at index= 136 , 15.52 was appended to plist
# at index= 136 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 137 and max p time= 15.53925
# at index= 137 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 138 and max p time= 15.705
# at index= 138 , 15.705 was appended to plist
# at index= 138 , 15.715 was appended to plist
# at index= 138 , 15.724 was appended to plist
# at index= 138 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 139 and max p time= 15.91075
# at index= 139 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 140 and max p time= 15.92075
# at index= 140 , 15.92075 was appended to plist
# at index= 140 , 15.92925 was appended to plist
# at index= 140 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 141 and max p time= 16.1055
# at index= 141 , 16.1055 was appended to plist
# at index= 141 , 1 peaks were added
# burst flag is now False
# burst flag is now True at index= 142 and max p time= 16.12575
# at index= 142 , 16.12575 was appended to plist
# at index= 142 , 16.13475 was appended to plist
# at index= 142 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 143 and max p time= 16.30875
# at index= 143 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 144 and max p time= 16.31975
# at index= 144 , 16.31975 was appended to plist
# at index= 144 , 16.3305 was appended to plist
# at index= 144 , 16.339 was appended to plist
# at index= 144 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 145 and max p time= 16.3575
# at index= 145 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 146 and max p time= 16.52425
# at index= 146 , 16.52425 was appended to plist
# at index= 146 , 16.5345 was appended to plist
# at index= 146 , 16.543 was appended to plist
# at index= 146 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 147 and max p time= 16.71925
# at index= 147 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 148 and max p time= 16.72875
# at index= 148 , 16.72875 was appended to plist
# at index= 148 , 16.73875 was appended to plist
# at index= 148 , 16.74725 was appended to plist
# at index= 148 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 149 and max p time= 16.9225
# at index= 149 , 16.9225 was appended to plist
# at index= 149 , 1 peaks were added
# burst flag is now False
# burst flag is now True at index= 150 and max p time= 16.943
# at index= 150 , 16.943 was appended to plist
# at index= 150 , 16.95175 was appended to plist
# at index= 150 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 151 and max p time= 17.137
# at index= 151 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 152 and max p time= 17.1475
# at index= 152 , 17.1475 was appended to plist
# at index= 152 , 17.156 was appended to plist
# at index= 152 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 153 and max p time= 17.34125
# at index= 153 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 154 and max p time= 17.351
# at index= 154 , 17.351 was appended to plist
# at index= 154 , 17.36 was appended to plist
# at index= 154 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 155 and max p time= 17.53725
# at index= 155 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 156 and max p time= 17.547
# at index= 156 , 17.547 was appended to plist
# at index= 156 , 17.557 was appended to plist
# at index= 156 , 17.566 was appended to plist
# at index= 156 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 157 and max p time= 17.74125
# at index= 157 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 158 and max p time= 17.752
# at index= 158 , 17.752 was appended to plist
# at index= 158 , 17.7625 was appended to plist
# at index= 158 , 17.77125 was appended to plist
# at index= 158 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 159 and max p time= 17.95725
# at index= 159 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 160 and max p time= 17.9675
# at index= 160 , 17.9675 was appended to plist
# at index= 160 , 17.976 was appended to plist
# at index= 160 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 161 and max p time= 18.1525
# at index= 161 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 162 and max p time= 18.16175
# at index= 162 , 18.16175 was appended to plist
# at index= 162 , 18.17175 was appended to plist
# at index= 162 , 18.1805 was appended to plist
# at index= 162 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 163 and max p time= 18.36575
# at index= 163 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 164 and max p time= 18.37625
# at index= 164 , 18.37625 was appended to plist
# at index= 164 , 18.385 was appended to plist
# at index= 164 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 165 and max p time= 18.57025
# at index= 165 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 166 and max p time= 18.581
# at index= 166 , 18.581 was appended to plist
# at index= 166 , 18.5895 was appended to plist
# at index= 166 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 167 and max p time= 18.77525
# at index= 167 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 168 and max p time= 18.785
# at index= 168 , 18.785 was appended to plist
# at index= 168 , 18.79375 was appended to plist
# at index= 168 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 169 and max p time= 18.97125
# at index= 169 , 18.97125 was appended to plist
# at index= 169 , 1 peaks were added
# burst flag is now False
# burst flag is now True at index= 170 and max p time= 18.99075
# at index= 170 , 18.99075 was appended to plist
# at index= 170 , 18.99975 was appended to plist
# at index= 170 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 171 and max p time= 19.17475
# at index= 171 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 172 and max p time= 19.18575
# at index= 172 , 19.18575 was appended to plist
# at index= 172 , 19.1965 was appended to plist
# at index= 172 , 19.20525 was appended to plist
# at index= 172 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 173 and max p time= 19.391
# at index= 173 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 174 and max p time= 19.40125
# at index= 174 , 19.40125 was appended to plist
# at index= 174 , 19.40975 was appended to plist
# at index= 174 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 175 and max p time= 19.586
# at index= 175 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 176 and max p time= 19.59525
# at index= 176 , 19.59525 was appended to plist
# at index= 176 , 19.6055 was appended to plist
# at index= 176 , 19.614 was appended to plist
# at index= 176 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 177 and max p time= 19.78925
# at index= 177 , 19.78925 was appended to plist
# at index= 177 , 1 peaks were added
# burst flag is now False
# burst flag is now True at index= 178 and max p time= 19.81025
# at index= 178 , 19.81025 was appended to plist
# at index= 178 , 19.819 was appended to plist
# at index= 178 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 179 and max p time= 19.993
# at index= 179 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 180 and max p time= 20.004
# at index= 180 , 20.004 was appended to plist
# at index= 180 , 20.01475 was appended to plist
# at index= 180 , 20.023 was appended to plist
# at index= 180 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 181 and max p time= 20.209
# at index= 181 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 182 and max p time= 20.219
# at index= 182 , 20.219 was appended to plist
# at index= 182 , 20.2275 was appended to plist
# at index= 182 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 183 and max p time= 20.4135
# at index= 183 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 184 and max p time= 20.4235
# at index= 184 , 20.4235 was appended to plist
# at index= 184 , 20.43325 was appended to plist
# at index= 184 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 185 and max p time= 20.60825
# at index= 185 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 186 and max p time= 20.6185
# at index= 186 , 20.6185 was appended to plist
# at index= 186 , 20.629 was appended to plist
# at index= 186 , 20.638 was appended to plist
# at index= 186 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 187 and max p time= 20.82425
# at index= 187 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 188 and max p time= 20.83425
# at index= 188 , 20.83425 was appended to plist
# at index= 188 , 20.84275 was appended to plist
# at index= 188 , 2 peaks were added
# burst flag is now False
# burst flag is now True at index= 189 and max p time= 21.01975
# at index= 189 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 190 and max p time= 21.029
# at index= 190 , 21.029 was appended to plist
# at index= 190 , 21.03925 was appended to plist
# at index= 190 , 21.048 was appended to plist
# at index= 190 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 191 and max p time= 21.223
# at index= 191 , 0 peaks were added
# burst flag is now False
# burst flag is now True at index= 192 and max p time= 21.23375
# at index= 192 , 21.23375 was appended to plist
# at index= 192 , 21.24425 was appended to plist
# at index= 192 , 21.253 was appended to plist
# at index= 192 , 3 peaks were added
# burst flag is now False
# burst flag is now True at index= 193 and max p time= 21.2725
# at index= 193 , 0 peaks were added
# burst flag is now False
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-133-f91f74e1b612> in <module>()
# ----> 1 burstpeak_num, burstpeaks, maxtabALL = burstpeaks(data_trans, bstart, bend, time=time[0])
#
# <ipython-input-128-1036cf80c481> in burstpeaks(data, burst_start, burst_end, time, delta)
#      43
#      44
# ---> 45             if burst_end[index] > time and burst == True: #is the peak inside the burst
#      46                 plist.append(time)#add time to list of peak times
#      47                 print "at index=", index, "," , time, "was appended to plist"
#
# IndexError: list index out of range

# %%
maxtabALL = np.array(maxtabALL)
maxptimeALL = maxtabALL[:,0]
maxptimeALL = (np.multiply(maxptimeALL,0.00025) + time[0])
maxpeaksALL = maxtabALL[:,1]
maxpeaksALL = (np.subtract(maxpeaksALL,base))

# %%
burstpeaksY = []
for point in burstpeaks

# %%
bendy = []
for point in bend:
    bendy.append(base*0.5)

# %%
bstarty = []
for point in bstart:
    bstarty.append(base*0.5)

# %%
fig = plt.plot(time,data_shift, color="k")
#plt.plot(time,data_trans,color='b')
#plt.plot(maxptimeALL,maxpeaksALL, marker = "^", color="g", linestyle= "None")
plt.plot(bstart, bstarty, marker = "v", color="y", linestyle= "None")
plt.plot(bend, bendy,marker = "v", color="m", linestyle= "None")
#plt.plot(minptime, minpeaks, marker ="v", color="m",  linestyle= "None")
plt.hlines(0,time[0],time[-1],colors='k')
plt.hlines((base*0.5),time[0],time[-1], colors='r')
DataCursor(fig)

# %%
plt.show(fig)

# %%
print data_trans[0:5]
print data_shift[0:5]
# Out:
# [ 0.0162657   0.01637714  0.01620614  0.01556582  0.01461065]
# [-0.03393484502707593, -0.033823404508265792, -0.03399440314027681, -0.034634719039026318, -0.035589891409805473]

# %%
x = time[0]

# %%
print x
# Out:
# 0.425

# %%
base
# Out:
# 0.050200543983550852

# %%
plt.hlines(0,time[0],time[-1])
