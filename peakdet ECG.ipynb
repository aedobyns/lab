# %%
import numpy as np
import scipy
from scipy import signal
import matplotlib.pyplot as plt
import sys

# %%
from numpy import NaN, Inf, arange, isscalar, asarray, array
 
def peakdet(v, delta, x = None):
    """
    Converted from MATLAB script at http://billauer.co.il/peakdet.html
    
    Returns two arrays
    
    function [maxtab, mintab]=peakdet(v, delta, x)
    # %PEAKDET Detect peaks in a vector
    %        [MAXTAB, MINTAB] = PEAKDET(V, DELTA) finds the local
    %        maxima and minima ("peaks") in the vector V.
    %        MAXTAB and MINTAB consists of two columns. Column 1
    %        contains indices in V, and column 2 the found values.
    %      
    %        With [MAXTAB, MINTAB] = PEAKDET(V, DELTA, X) the indices
    %        in MAXTAB and MINTAB are replaced with the corresponding
    %        X-values.
    %
    %        A point is considered a maximum peak if it has the maximal
    %        value, and was preceded (to the left) by a value lower by
    %        DELTA.
    
    % Eli Billauer, 3.4.05 (Explicitly not copyrighted).
    % This function is released to the public domain; Any use is allowed.
    
    """
    maxtab = []
    mintab = []
       
    if x is None:
        x = arange(len(v))
    
    v = asarray(v)
    
    if len(v) != len(x):
        sys.exit('Input vectors v and x must have same length')
    
    if not isscalar(delta):
        sys.exit('Input argument delta must be a scalar')
    
    if delta <= 0:
        sys.exit('Input argument delta must be positive')
    
    mn, mx = Inf, -Inf
    mnpos, mxpos = NaN, NaN
    
    lookformax = True
    
    for i in arange(len(v)):
        this = v[i]
        if this > mx:
            mx = this
            mxpos = x[i]
        if this < mn:
            mn = this
            mnpos = x[i]
        
        if lookformax:
            if this < mx-delta:
                maxtab.append((mxpos, mx))
                mn = this
                mnpos = x[i]
                lookformax = False
        else:
            if this > mn+delta:
                mintab.append((mnpos, mn))
                mx = this
                mxpos = x[i]
                lookformax = True
 
    return array(maxtab), array(mintab)

# %%
from matplotlib import cbook

class DataCursor(object):
    """A simple data cursor widget that displays the x,y location of a
    matplotlib artist when it is selected."""
    def __init__(self, artists, tolerance=5, offsets=(-20, 20), 
                 template='x: %0.2f\ny: %0.2f', display_all=False):
        """Create the data cursor and connect it to the relevant figure.
        "artists" is the matplotlib artist or sequence of artists that will be 
            selected. 
        "tolerance" is the radius (in points) that the mouse click must be
            within to select the artist.
        "offsets" is a tuple of (x,y) offsets in points from the selected
            point to the displayed annotation box
        "template" is the format string to be used. Note: For compatibility
            with older versions of python, this uses the old-style (%) 
            formatting specification.
        "display_all" controls whether more than one annotation box will
            be shown if there are multiple axes.  Only one will be shown
            per-axis, regardless. 
        """
        self.template = template
        self.offsets = offsets
        self.display_all = display_all
        if not cbook.iterable(artists):
            artists = [artists]
        self.artists = artists
        self.axes = tuple(set(art.axes for art in self.artists))
        self.figures = tuple(set(ax.figure for ax in self.axes))

        self.annotations = {}
        for ax in self.axes:
            self.annotations[ax] = self.annotate(ax)

        for artist in self.artists:
            artist.set_picker(tolerance)
        for fig in self.figures:
            fig.canvas.mpl_connect('pick_event', self)

    def annotate(self, ax):
        """Draws and hides the annotation box for the given axis "ax"."""
        annotation = ax.annotate(self.template, xy=(0, 0), ha='right',
                xytext=self.offsets, textcoords='offset points', va='bottom',
                bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
                arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0')
                )
        annotation.set_visible(False)
        return annotation

    def __call__(self, event):
        """Intended to be called through "mpl_connect"."""
        # Rather than trying to interpolate, just display the clicked coords
        # This will only be called if it's within "tolerance", anyway.
        x, y = event.mouseevent.xdata, event.mouseevent.ydata
        annotation = self.annotations[event.artist.axes]
        if x is not None:
            if not self.display_all:
                # Hide any other annotation boxes...
                for ann in self.annotations.values():
                    ann.set_visible(False)
            # Update the annotation in the current axis..
            annotation.xy = x, y
            annotation.set_text(self.template % (x, y))
            annotation.set_visible(True)
            event.canvas.draw()

#if __name__ == '__main__':
    #import matplotlib.pyplot as plt
    #plt.figure()
    #plt.subplot(2,1,1)
    #line1, = plt.plot(range(10), 'ro-')
    #plt.subplot(2,1,2)
    #line2, = plt.plot(range(10), 'bo-')

    #DataCursor([line1, line2])

# %%
def baseline(data,rate):
    
    '''
    input data array and rate value.
    using the first 0.2 s of data, find average of all data values. this becomes the baseline.
    baseline is used later in burst measurements
    import numpy as np
    '''
    
    index = 0.2/rate #find the index of the first 0.2 seconds of data
    baserate = np.mean(data[:index]) #average all points to obtain baserate
    
    datashift = []
    
    #may be able to use np.subtract(data,base) instead, but this seems to work correctly.
    for x in data:
        foo = (x-baserate)
        datashift.append(foo)
        
    return baserate, datashift

# %%
def burstduration(time, data, baserate, threshperc=0.2, clusterperc=0.006):
    """
    threshperc should be 0<= x <= 1; clusterperc should be changed based on the type of data (default for ECG is 0.006)
    baserate needs to be calculated and passed into this argument
    data should already be transformed, smoothed, and baseline shifted (shifting is technically optional, but it really doesn't matter)
    """
    
    if len(time) != len(data): #logic check, are the number of data points and time points the same?
        sys.exit('You cannot have more time points than there are data points. Get that sorted, buddy.')    
    
    burst_start = [] #empty array for burst start
    burst_end = [] #empty array for burst end
    burst_duration = [] #empty array to calculate burst durration
    
    threshold = baserate * threshperc #calculate the point at which a event is considered a peak
    
    burst = False #burst flag, should start not in a burst

    for point in data: #for each data point in the set
        
        timeindex = data.index(point) #find the time index of a given data point
        tpoint = time[timeindex] #find the actual time given teh time index
        
        if burst == False and point > threshold: #if we are not in a burst already, the value is higher than the threshold, AND the last burst didn't end less than .2 ms ago
            burst_start.append(tpoint) #add the time at point as the begining of the burst
            burst = True #burst flag, we are now in a burst 
        
        if burst == True and  point <= threshold: #if we are in a burst and the point falls below the threshold
            
            if len(burst_end) == 0 or len(burst_start) == 0: #if this is the first end
                burst_end.append (tpoint) #add the time at point as the end of the burst
                burst = False #burst flag, we are now out of the burst
    
            #elif burst_start[-1] > (burst_end[-1] + 0.0007): #if the start time and the last end time are too close together, don't add it as a seperate burst
            #    del burst_end[-1] #delete the last end time
             #   burst_end.append(tpoint) #replace it with the new end time
              #  del burst_start[-1] #get rid of new start time, since it isn't really a new start time
            
            else:
                burst_end.append (tpoint) #add the time at point as the end of the burst
                burst = False #burst flag, we are now out of the burst
                if burst_start[-1] < (burst_end[-2] + clusterperc):
                    del burst_end[-2]
                    del burst_start[-1]
    
    if len(burst_start) != len(burst_end):
        sys.exit('Unexpectedly, the number of burst start times and end times are not equal. Seeing as this is physically impossible, I quit the program for you. Begin hunting for the fatal flaw. Good luck!')
        
    
    for foo in burst_start: #for each burst
        index = burst_start.index(foo)
        duration = burst_end[index] - burst_start[index] #calculate duration by subtracting the start time from the end time, found by indexing
        burst_duration.append(duration) #add the burst duration to the duration list
    
    return burst_start, burst_end, burst_duration

# %%
def ibi(burst_start, burst_end):
    """
    this function is used to find the inter-burst interval. 
    this is defined as the difference between the last end and the new start time
    Dependent on numpy, burst_start, and burst_end
    """
    
    ibi = []
    
    for end in burst_end[:-1]: #for each end time except the last one
        tindex = burst_end.index(end) #find the start time index
        start = burst_start[tindex+1] #find start time
        ibi.append(start-end) #subtract the old end time from the start time
    
    return ibi

# %%
def ttot(burst_start): 
    """
    find time from start to start, called the interburst interval. Input array must be a list of numbers (float).
    """
    
    ttotal = [] #empty array for ttot to go into
    
    for time in burst_start[1:]: #for each start time, starting with the second one
        s2time = burst_start.index(time) 
        s2 = burst_start[s2time-1]
        meas = time - s2 #measure the interval by subtracting
        ttotal.append(meas) #append the measurement to the ttotal array
    return ttotal #return array

# %%
def burstarea(data, time, burst_start, burst_end, dx = 10):
    """
    integral, area under curve of each burst. Use start and end times to split the y values into short lists. 
    need the time array to do this
    """
    from scipy.integrate import simps, trapz #import the integral functions
    
    time = list(time) #time array must be a list for the indexting to work.
    
    burst_area = [] #empty array for the areas to go into
    
    for i in np.arange(len(burst_start)): #for each index in the start array
        end = time.index(burst_end[i]) #using the value at each i in the burst_end array, index in the time array to get the time index. this will be the same index # as the data array
        start = time.index(burst_start[i])
        area = trapz(data[start:end], x=time[start:end], dx= dx) #find area using the trapz function, but only 
        burst_area.append(area)
    
    return burst_area

# %%
def burstpeaks(data, burst_start, burst_end, time=0, delta=0.04, rate=0.00025):
    """
    given the burst start and end time, along with the looser peak detect, calculate the number of peaks in a given burst
    dependent on burstduration, numpy, sys, and peakdet
    default delta is 0.04, based on ECG data, seems to catch QRS and sometimes P and/or T
    data MUST be transformed, but not shifted. peakdet will reject it if it has negative values
    time varible is the value of time at the the first index of the time array. You can input it in as time=TIME_ARRAY[0]
    rate is the collection rate of the data set. 
    """
    
    if len(burst_start) != len(burst_end): #logic check, before we start
        sys.exit('Unexpectedly, the number of burst start times and end times are not equal. Seeing as this is physically impossible, I quit the program for you. Begin hunting for the fatal flaw. Good luck!')
    
    if (len(burst_start) == 0) or (len(burst_end) == 0): #logic check, are they empty lists
        sys.exit('One of the input arrays is an empty list')
        
    maxtab, mintab= peakdet(data, delta) #generate the maxtab array of times and heights
    
    maxptime = maxtab[:,0]
    maxptime = (np.multiply(maxptime,rate) + time)
    
    index = 0 #initalize burst index to zero
    burstpeaknum = [] #empty array for where the number of peaks will go. index # = burst #
    burstpeaks = [] #empty tuple of peak locations. index # = burst #
    plist= [] #make blank plist
    
    
    for time in maxptime: #for each peak found in maxtab. remember that maxtab has multipule columns, so only take time.
        
        if time >= burst_end[-1]:
            print "peak outside of last burst, BREAK!"
            break
        
        if burst_start[index] < time < burst_end[index]: # if the peak is within the duration of the burst
            plist.append(time)
            print "at burst", index, ", ", time, "was added"
            if time == maxptime[-1]:
                burstpeaks.append(plist) #put list of peaks in burst peaks list
                burstpeaknum.append(len(plist)) #add count of peaks to burst peak num list
                print "the last peak was inside the last burst"
    
        
        if index < (len(burst_start)-1) and time > burst_start[index+1]: #if the next peak is actually in the NEXT burst AND it isn't the last burst
            burstpeaks.append(plist) #put list of peaks in burst peaks list
            burstpeaknum.append(len(plist)) #add count of peaks to burst peak num list
            print "burst", index, "has ", len(plist), "peaks"
            index = (index+1) #go to the next peak
            print "new burst!"
            plist=[] #make a new list for the new peak
            plist.append(time) #add this timepoint to the new list
            print "at burst", index, ", ", time, "was added"
        
           
    return burstpeaknum, burstpeaks, maxtab

# %%
def savitzky_golay(y, window_size, order, deriv=0, rate=1):
    r"""Smooth (and optionally differentiate) data with a Savitzky-Golay filter.
    The Savitzky-Golay filter removes high frequency noise from data.
    It has the advantage of preserving the original shape and
    features of the signal better than other types of filtering
    approaches, such as moving averages techniques.
    Parameters
    ----------
    y : array_like, shape (N,)
        the values of the time history of the signal.
    window_size : int
        the length of the window. Must be an odd integer number.
    order : int
        the order of the polynomial used in the filtering.
        Must be less then `window_size` - 1.
    deriv: int
        the order of the derivative to compute (default = 0 means only smoothing)
    Returns
    -------
    ys : ndarray, shape (N)
        the smoothed signal (or it's n-th derivative).
    Notes
    -----
    The Savitzky-Golay is a type of low-pass filter, particularly
    suited for smoothing noisy data. The main idea behind this
    approach is to make for each point a least-square fit with a
    polynomial of high order over a odd-sized window centered at
    the point.
    Examples
    --------
    t = np.linspace(-4, 4, 500)
    y = np.exp( -t**2 ) + np.random.normal(0, 0.05, t.shape)
    ysg = savitzky_golay(y, window_size=31, order=4)
    import matplotlib.pyplot as plt
    plt.plot(t, y, label='Noisy signal')
    plt.plot(t, np.exp(-t**2), 'k', lw=1.5, label='Original signal')
    plt.plot(t, ysg, 'r', label='Filtered signal')
    plt.legend()
    plt.show()
    References
    ----------
    .. [1] A. Savitzky, M. J. E. Golay, Smoothing and Differentiation of
       Data by Simplified Least Squares Procedures. Analytical
       Chemistry, 1964, 36 (8), pp 1627-1639.
    .. [2] Numerical Recipes 3rd Edition: The Art of Scientific Computing
       W.H. Press, S.A. Teukolsky, W.T. Vetterling, B.P. Flannery
       Cambridge University Press ISBN-13: 9780521880688
    """
    import numpy as np
    from math import factorial

    try:
        window_size = np.abs(np.int(window_size))
        order = np.abs(np.int(order))
    except ValueError, msg:
        raise ValueError("window_size and order have to be of type int")
    if window_size % 2 != 1 or window_size < 1:
        raise TypeError("window_size size must be a positive odd number")
    if window_size < order + 2:
        raise TypeError("window_size is too small for the polynomials order")
    order_range = range(order+1)
    half_window = (window_size -1) // 2
    # precompute coefficients
    b = np.mat([[k**i for i in order_range] for k in range(-half_window, half_window+1)])
    m = np.linalg.pinv(b).A[deriv] * rate**deriv * factorial(deriv)
    # pad the signal at the extremes with
    # values taken from the signal itself
    firstvals = y[0] - np.abs( y[1:half_window+1][::-1] - y[0] )
    lastvals = y[-1] + np.abs(y[-half_window-1:-1][::-1] - y[-1])
    y = np.concatenate((firstvals, y, lastvals))
    return np.convolve( m[::-1], y, mode='valid')

# %% [markdown]
# end functions
# begin user input

# %%
time, data = np.loadtxt("/Users/abigaildobyns/Dropbox/Wilson_lab_papers/Abby/data/2014-29-04rat56-ECG.txt", delimiter="\t", usecols=(0,1),  unpack=True)
widths = np.loadtxt("/Users/abigaildobyns/Dropbox/Wilson_lab_papers/Abby/data/widths.txt", delimiter= "\t", unpack=True)
time = time[1800:]
data = data[1800:]

# %%
data_trans = abs(data)
data_trans =savitzky_golay(data_trans, 47, 4)

# %%
base, data_shift =baseline(data_trans,0.00025)

# %% [markdown]
# peakdet **CANNOT** take negative values, so base_shift cannot be used to calculate the peaks.

# %%
maxtab, mintab = peakdet(data_trans, 0.6, None)

# %%
maxtab = np.array(maxtab)
maxptime = maxtab[:,0]
maxptime = (np.multiply(maxptime,0.00025) + time[0])
maxpeaks = maxtab[:,1]
maxpeaks = (np.subtract(maxpeaks,base))

# %% [markdown]
# mintab = np.array(mintab)
# minptime = mintab[:,0]
# minptime = (np.multiply(minptime,0.00025) + time[0])
# minpeaks = mintab[:,1]

# %%
bstart, bend, bdur = burstduration(time, data_shift, base, threshperc=0.5)

# %%
len(bend) == len(bstart)
# Out:
# True

# %%
print len(bend)
print len(bstart)
# Out:
# 111
# 111

# %%
x = ibi(bstart, bend)
print len(x)
# Out:
# 110

# %%
tot = ttot(bstart)
print len(tot)
# Out:
# 110

# %%
x[:5]
# Out:
# [0.1705000000000001,
#  0.17649999999999988,
#  0.1692499999999999,
#  0.0064999999999999503,
#  0.17599999999999993]

# %%
b_area = burstarea(data_trans, time, bstart, bend)

# %%
b_area[0:5]
# Out:
# [0.0068102428750570036,
#  0.0082884187051366822,
#  0.0071816454768696102,
#  7.7317072004448131e-05,
#  0.0080478914929653349]

# %%
burstpeak_num, burstpeaks, maxtabALL = burstpeaks(data_trans, bstart, bend, time=time[0])
# Out:
# at burst 0 ,  1.04075 was added
# at burst 0 ,  1.051 was added
# at burst 0 ,  1.05975 was added
# at burst 0 ,  1.0685 was added
# burst 0 has  4 peaks
# new burst!
# at burst 1 ,  1.241 was added
# at burst 1 ,  1.251 was added
# at burst 1 ,  1.26125 was added
# at burst 1 ,  1.27025 was added
# at burst 1 ,  1.27975 was added
# burst 1 has  5 peaks
# new burst!
# at burst 2 ,  1.4605 was added
# at burst 2 ,  1.47075 was added
# at burst 2 ,  1.47925 was added
# at burst 2 ,  1.488 was added
# burst 2 has  4 peaks
# new burst!
# at burst 3 ,  1.65875 was added
# burst 3 has  1 peaks
# new burst!
# at burst 4 ,  1.66925 was added
# at burst 4 ,  1.68 was added
# at burst 4 ,  1.6885 was added
# at burst 4 ,  1.698 was added
# burst 4 has  4 peaks
# new burst!
# at burst 5 ,  1.8785 was added
# at burst 5 ,  1.88875 was added
# at burst 5 ,  1.897 was added
# burst 5 has  3 peaks
# new burst!
# at burst 6 ,  2.08675 was added
# at burst 6 ,  2.0975 was added
# at burst 6 ,  2.106 was added
# at burst 6 ,  2.1155 was added
# burst 6 has  4 peaks
# new burst!
# at burst 7 ,  2.2955 was added
# at burst 7 ,  2.3055 was added
# at burst 7 ,  2.314 was added
# burst 7 has  3 peaks
# new burst!
# at burst 8 ,  2.5035 was added
# at burst 8 ,  2.51425 was added
# at burst 8 ,  2.52275 was added
# at burst 8 ,  2.53225 was added
# burst 8 has  4 peaks
# new burst!
# at burst 9 ,  2.71225 was added
# at burst 9 ,  2.72225 was added
# at burst 9 ,  2.731 was added
# burst 9 has  3 peaks
# new burst!
# at burst 10 ,  2.92175 was added
# at burst 10 ,  2.93225 was added
# at burst 10 ,  2.941 was added
# at burst 10 ,  2.95 was added
# burst 10 has  4 peaks
# new burst!
# at burst 11 ,  3.131 was added
# at burst 11 ,  3.141 was added
# at burst 11 ,  3.14975 was added
# burst 11 has  3 peaks
# new burst!
# at burst 12 ,  3.339 was added
# at burst 12 ,  3.35 was added
# at burst 12 ,  3.35825 was added
# at burst 12 ,  3.367 was added
# burst 12 has  4 peaks
# new burst!
# at burst 13 ,  3.54725 was added
# at burst 13 ,  3.55725 was added
# at burst 13 ,  3.566 was added
# burst 13 has  3 peaks
# new burst!
# at burst 14 ,  3.75475 was added
# at burst 14 ,  3.76575 was added
# at burst 14 ,  3.774 was added
# at burst 14 ,  3.783 was added
# burst 14 has  4 peaks
# new burst!
# at burst 15 ,  3.9635 was added
# at burst 15 ,  3.9735 was added
# at burst 15 ,  3.982 was added
# burst 15 has  3 peaks
# new burst!
# at burst 16 ,  4.171 was added
# at burst 16 ,  4.18175 was added
# at burst 16 ,  4.19025 was added
# at burst 16 ,  4.19925 was added
# burst 16 has  4 peaks
# new burst!
# at burst 17 ,  4.3795 was added
# at burst 17 ,  4.389 was added
# at burst 17 ,  4.398 was added
# burst 17 has  3 peaks
# new burst!
# at burst 18 ,  4.587 was added
# at burst 18 ,  4.5975 was added
# at burst 18 ,  4.60625 was added
# at burst 18 ,  4.6155 was added
# burst 18 has  4 peaks
# new burst!
# at burst 19 ,  4.7955 was added
# at burst 19 ,  4.8055 was added
# at burst 19 ,  4.814 was added
# burst 19 has  3 peaks
# new burst!
# at burst 20 ,  5.0025 was added
# at burst 20 ,  5.01325 was added
# at burst 20 ,  5.02175 was added
# at burst 20 ,  5.03125 was added
# burst 20 has  4 peaks
# new burst!
# at burst 21 ,  5.21025 was added
# at burst 21 ,  5.2205 was added
# at burst 21 ,  5.22875 was added
# at burst 21 ,  5.2375 was added
# burst 21 has  4 peaks
# new burst!
# at burst 22 ,  5.40725 was added
# at burst 22 ,  5.417 was added
# at burst 22 ,  5.4275 was added
# at burst 22 ,  5.4365 was added
# at burst 22 ,  5.44625 was added
# burst 22 has  5 peaks
# new burst!
# at burst 23 ,  5.62425 was added
# at burst 23 ,  5.635 was added
# at burst 23 ,  5.64325 was added
# at burst 23 ,  5.652 was added
# burst 23 has  4 peaks
# new burst!
# at burst 24 ,  5.8225 was added
# burst 24 has  1 peaks
# new burst!
# at burst 25 ,  5.8315 was added
# at burst 25 ,  5.84175 was added
# at burst 25 ,  5.8505 was added
# burst 25 has  3 peaks
# new burst!
# at burst 26 ,  6.0385 was added
# at burst 26 ,  6.04875 was added
# at burst 26 ,  6.05775 was added
# at burst 26 ,  6.0665 was added
# burst 26 has  4 peaks
# new burst!
# at burst 27 ,  6.24625 was added
# at burst 27 ,  6.25625 was added
# at burst 27 ,  6.265 was added
# burst 27 has  3 peaks
# new burst!
# at burst 28 ,  6.453 was added
# at burst 28 ,  6.46375 was added
# at burst 28 ,  6.47225 was added
# at burst 28 ,  6.4815 was added
# burst 28 has  4 peaks
# new burst!
# at burst 29 ,  6.6605 was added
# at burst 29 ,  6.6705 was added
# at burst 29 ,  6.67875 was added
# at burst 29 ,  6.68775 was added
# burst 29 has  4 peaks
# new burst!
# at burst 30 ,  6.857 was added
# at burst 30 ,  6.86675 was added
# at burst 30 ,  6.87725 was added
# at burst 30 ,  6.88575 was added
# at burst 30 ,  6.896 was added
# burst 30 has  5 peaks
# new burst!
# at burst 31 ,  7.0735 was added
# at burst 31 ,  7.08425 was added
# at burst 31 ,  7.09225 was added
# at burst 31 ,  7.10125 was added
# burst 31 has  4 peaks
# new burst!
# at burst 32 ,  7.28 was added
# at burst 32 ,  7.29 was added
# at burst 32 ,  7.29875 was added
# burst 32 has  3 peaks
# new burst!
# at burst 33 ,  7.48575 was added
# at burst 33 ,  7.4965 was added
# at burst 33 ,  7.50525 was added
# at burst 33 ,  7.5145 was added
# burst 33 has  4 peaks
# new burst!
# at burst 34 ,  7.69225 was added
# at burst 34 ,  7.70225 was added
# at burst 34 ,  7.711 was added
# at burst 34 ,  7.71975 was added
# burst 34 has  4 peaks
# new burst!
# at burst 35 ,  7.8895 was added
# at burst 35 ,  7.89925 was added
# at burst 35 ,  7.90925 was added
# at burst 35 ,  7.91825 was added
# at burst 35 ,  7.92825 was added
# burst 35 has  5 peaks
# new burst!
# at burst 36 ,  8.1055 was added
# at burst 36 ,  8.11625 was added
# at burst 36 ,  8.12475 was added
# at burst 36 ,  8.1335 was added
# burst 36 has  4 peaks
# new burst!
# at burst 37 ,  8.312 was added
# at burst 37 ,  8.322 was added
# at burst 37 ,  8.33075 was added
# burst 37 has  3 peaks
# new burst!
# at burst 38 ,  8.5175 was added
# burst 38 has  1 peaks
# new burst!
# at burst 39 ,  8.52825 was added
# at burst 39 ,  8.537 was added
# at burst 39 ,  8.54675 was added
# burst 39 has  3 peaks
# new burst!
# at burst 40 ,  8.72375 was added
# at burst 40 ,  8.73425 was added
# at burst 40 ,  8.7425 was added
# at burst 40 ,  8.7515 was added
# burst 40 has  4 peaks
# new burst!
# at burst 41 ,  8.9295 was added
# at burst 41 ,  8.93975 was added
# at burst 41 ,  8.94825 was added
# burst 41 has  3 peaks
# new burst!
# at burst 42 ,  9.135 was added
# at burst 42 ,  9.1455 was added
# at burst 42 ,  9.1545 was added
# at burst 42 ,  9.164 was added
# burst 42 has  4 peaks
# new burst!
# at burst 43 ,  9.34225 was added
# at burst 43 ,  9.352 was added
# at burst 43 ,  9.36075 was added
# at burst 43 ,  9.3695 was added
# burst 43 has  4 peaks
# new burst!
# at burst 44 ,  9.53875 was added
# at burst 44 ,  9.54825 was added
# at burst 44 ,  9.5585 was added
# at burst 44 ,  9.56725 was added
# at burst 44 ,  9.577 was added
# burst 44 has  5 peaks
# new burst!
# at burst 45 ,  9.754 was added
# at burst 45 ,  9.76475 was added
# at burst 45 ,  9.77325 was added
# at burst 45 ,  9.78225 was added
# burst 45 has  4 peaks
# new burst!
# at burst 46 ,  9.9605 was added
# at burst 46 ,  9.9705 was added
# at burst 46 ,  9.97875 was added
# at burst 46 ,  9.988 was added
# burst 46 has  4 peaks
# new burst!
# at burst 47 ,  10.15625 was added
# burst 47 has  1 peaks
# new burst!
# at burst 48 ,  10.166 was added
# at burst 48 ,  10.1765 was added
# at burst 48 ,  10.18525 was added
# at burst 48 ,  10.195 was added
# burst 48 has  4 peaks
# new burst!
# at burst 49 ,  10.37175 was added
# at burst 49 ,  10.3825 was added
# at burst 49 ,  10.39075 was added
# at burst 49 ,  10.39975 was added
# burst 49 has  4 peaks
# new burst!
# at burst 50 ,  10.57775 was added
# at burst 50 ,  10.58775 was added
# at burst 50 ,  10.59625 was added
# burst 50 has  3 peaks
# new burst!
# at burst 51 ,  10.7735 was added
# burst 51 has  1 peaks
# new burst!
# at burst 52 ,  10.78275 was added
# at burst 52 ,  10.79325 was added
# at burst 52 ,  10.8025 was added
# at burst 52 ,  10.812 was added
# burst 52 has  4 peaks
# new burst!
# at burst 53 ,  10.98925 was added
# at burst 53 ,  10.9995 was added
# at burst 53 ,  11.00825 was added
# at burst 53 ,  11.01725 was added
# burst 53 has  4 peaks
# new burst!
# at burst 54 ,  11.1955 was added
# at burst 54 ,  11.2055 was added
# at burst 54 ,  11.21425 was added
# burst 54 has  3 peaks
# new burst!
# at burst 55 ,  11.40075 was added
# burst 55 has  1 peaks
# new burst!
# at burst 56 ,  11.41125 was added
# at burst 56 ,  11.42025 was added
# at burst 56 ,  11.42975 was added
# burst 56 has  3 peaks
# new burst!
# at burst 57 ,  11.6065 was added
# at burst 57 ,  11.617 was added
# at burst 57 ,  11.6255 was added
# at burst 57 ,  11.63425 was added
# burst 57 has  4 peaks
# new burst!
# at burst 58 ,  11.812 was added
# at burst 58 ,  11.82225 was added
# at burst 58 ,  11.83075 was added
# burst 58 has  3 peaks
# new burst!
# at burst 59 ,  12.017 was added
# burst 59 has  1 peaks
# new burst!
# at burst 60 ,  12.02775 was added
# at burst 60 ,  12.0365 was added
# at burst 60 ,  12.046 was added
# burst 60 has  3 peaks
# new burst!
# at burst 61 ,  12.22225 was added
# at burst 61 ,  12.23275 was added
# at burst 61 ,  12.24125 was added
# at burst 61 ,  12.25 was added
# burst 61 has  4 peaks
# new burst!
# at burst 62 ,  12.4275 was added
# at burst 62 ,  12.437 was added
# at burst 62 ,  12.446 was added
# burst 62 has  3 peaks
# new burst!
# at burst 63 ,  12.6235 was added
# burst 63 has  1 peaks
# new burst!
# at burst 64 ,  12.6335 was added
# at burst 64 ,  12.644 was added
# at burst 64 ,  12.653 was added
# at burst 64 ,  12.6625 was added
# burst 64 has  4 peaks
# new burst!
# at burst 65 ,  12.839 was added
# at burst 65 ,  12.8495 was added
# at burst 65 ,  12.858 was added
# at burst 65 ,  12.867 was added
# burst 65 has  4 peaks
# new burst!
# at burst 66 ,  13.0445 was added
# at burst 66 ,  13.0545 was added
# at burst 66 ,  13.063 was added
# burst 66 has  3 peaks
# new burst!
# at burst 67 ,  13.23925 was added
# at burst 67 ,  13.249 was added
# at burst 67 ,  13.2595 was added
# at burst 67 ,  13.26825 was added
# at burst 67 ,  13.278 was added
# burst 67 has  5 peaks
# new burst!
# at burst 68 ,  13.45375 was added
# at burst 68 ,  13.46475 was added
# at burst 68 ,  13.473 was added
# at burst 68 ,  13.482 was added
# burst 68 has  4 peaks
# new burst!
# at burst 69 ,  13.65875 was added
# at burst 69 ,  13.669 was added
# at burst 69 ,  13.67725 was added
# at burst 69 ,  13.68625 was added
# burst 69 has  4 peaks
# new burst!
# at burst 70 ,  13.863 was added
# at burst 70 ,  13.87325 was added
# at burst 70 ,  13.882 was added
# burst 70 has  3 peaks
# new burst!
# at burst 71 ,  14.067 was added
# at burst 71 ,  14.0775 was added
# at burst 71 ,  14.087 was added
# at burst 71 ,  14.09625 was added
# burst 71 has  4 peaks
# new burst!
# at burst 72 ,  14.27325 was added
# at burst 72 ,  14.2835 was added
# at burst 72 ,  14.292 was added
# at burst 72 ,  14.30075 was added
# burst 72 has  4 peaks
# new burst!
# at burst 73 ,  14.4785 was added
# at burst 73 ,  14.4885 was added
# at burst 73 ,  14.49725 was added
# burst 73 has  3 peaks
# new burst!
# at burst 74 ,  14.673 was added
# at burst 74 ,  14.683 was added
# at burst 74 ,  14.6935 was added
# at burst 74 ,  14.70225 was added
# at burst 74 ,  14.712 was added
# burst 74 has  5 peaks
# new burst!
# at burst 75 ,  14.8875 was added
# at burst 75 ,  14.89825 was added
# at burst 75 ,  14.9065 was added
# at burst 75 ,  14.91575 was added
# burst 75 has  4 peaks
# new burst!
# at burst 76 ,  15.09225 was added
# at burst 76 ,  15.10225 was added
# at burst 76 ,  15.11075 was added
# at burst 76 ,  15.1195 was added
# burst 76 has  4 peaks
# new burst!
# at burst 77 ,  15.2965 was added
# at burst 77 ,  15.30675 was added
# at burst 77 ,  15.31525 was added
# at burst 77 ,  15.32525 was added
# burst 77 has  4 peaks
# new burst!
# at burst 78 ,  15.49075 was added
# at burst 78 ,  15.5005 was added
# at burst 78 ,  15.511 was added
# at burst 78 ,  15.52 was added
# at burst 78 ,  15.52925 was added
# burst 78 has  5 peaks
# new burst!
# at burst 79 ,  15.705 was added
# at burst 79 ,  15.715 was added
# at burst 79 ,  15.724 was added
# at burst 79 ,  15.73275 was added
# burst 79 has  4 peaks
# new burst!
# at burst 80 ,  15.91075 was added
# at burst 80 ,  15.92075 was added
# at burst 80 ,  15.92925 was added
# burst 80 has  3 peaks
# new burst!
# at burst 81 ,  16.1055 was added
# at burst 81 ,  16.11525 was added
# at burst 81 ,  16.12575 was added
# at burst 81 ,  16.13475 was added
# at burst 81 ,  16.1445 was added
# burst 81 has  5 peaks
# new burst!
# at burst 82 ,  16.31975 was added
# at burst 82 ,  16.3305 was added
# at burst 82 ,  16.339 was added
# at burst 82 ,  16.34825 was added
# burst 82 has  4 peaks
# new burst!
# at burst 83 ,  16.52425 was added
# at burst 83 ,  16.5345 was added
# at burst 83 ,  16.543 was added
# at burst 83 ,  16.5515 was added
# burst 83 has  4 peaks
# new burst!
# at burst 84 ,  16.72875 was added
# at burst 84 ,  16.73875 was added
# at burst 84 ,  16.74725 was added
# burst 84 has  3 peaks
# new burst!
# at burst 85 ,  16.9225 was added
# burst 85 has  1 peaks
# new burst!
# at burst 86 ,  16.9325 was added
# at burst 86 ,  16.943 was added
# at burst 86 ,  16.95175 was added
# at burst 86 ,  16.9615 was added
# burst 86 has  4 peaks
# new burst!
# at burst 87 ,  17.137 was added
# at burst 87 ,  17.1475 was added
# at burst 87 ,  17.156 was added
# at burst 87 ,  17.16525 was added
# burst 87 has  4 peaks
# new burst!
# at burst 88 ,  17.34125 was added
# at burst 88 ,  17.351 was added
# at burst 88 ,  17.36 was added
# at burst 88 ,  17.36875 was added
# burst 88 has  4 peaks
# new burst!
# at burst 89 ,  17.547 was added
# at burst 89 ,  17.557 was added
# at burst 89 ,  17.566 was added
# at burst 89 ,  17.576 was added
# burst 89 has  4 peaks
# new burst!
# at burst 90 ,  17.752 was added
# at burst 90 ,  17.7625 was added
# at burst 90 ,  17.77125 was added
# at burst 90 ,  17.78025 was added
# burst 90 has  4 peaks
# new burst!
# at burst 91 ,  17.95725 was added
# at burst 91 ,  17.9675 was added
# at burst 91 ,  17.976 was added
# at burst 91 ,  17.9845 was added
# burst 91 has  4 peaks
# new burst!
# at burst 92 ,  18.16175 was added
# at burst 92 ,  18.17175 was added
# at burst 92 ,  18.1805 was added
# burst 92 has  3 peaks
# new burst!
# at burst 93 ,  18.35575 was added
# at burst 93 ,  18.36575 was added
# at burst 93 ,  18.37625 was added
# at burst 93 ,  18.385 was added
# at burst 93 ,  18.39475 was added
# burst 93 has  5 peaks
# new burst!
# at burst 94 ,  18.57025 was added
# at burst 94 ,  18.581 was added
# at burst 94 ,  18.5895 was added
# at burst 94 ,  18.5985 was added
# burst 94 has  4 peaks
# new burst!
# at burst 95 ,  18.77525 was added
# at burst 95 ,  18.785 was added
# at burst 95 ,  18.79375 was added
# burst 95 has  3 peaks
# new burst!
# at burst 96 ,  18.97125 was added
# at burst 96 ,  18.9805 was added
# at burst 96 ,  18.99075 was added
# at burst 96 ,  18.99975 was added
# at burst 96 ,  19.0095 was added
# burst 96 has  5 peaks
# new burst!
# at burst 97 ,  19.18575 was added
# at burst 97 ,  19.1965 was added
# at burst 97 ,  19.20525 was added
# at burst 97 ,  19.21425 was added
# burst 97 has  4 peaks
# new burst!
# at burst 98 ,  19.391 was added
# at burst 98 ,  19.40125 was added
# at burst 98 ,  19.40975 was added
# at burst 98 ,  19.4185 was added
# burst 98 has  4 peaks
# new burst!
# at burst 99 ,  19.59525 was added
# at burst 99 ,  19.6055 was added
# at burst 99 ,  19.614 was added
# burst 99 has  3 peaks
# new burst!
# at burst 100 ,  19.78925 was added
# burst 100 has  1 peaks
# new burst!
# at burst 101 ,  19.7995 was added
# at burst 101 ,  19.81025 was added
# at burst 101 ,  19.819 was added
# at burst 101 ,  19.82875 was added
# burst 101 has  4 peaks
# new burst!
# at burst 102 ,  20.004 was added
# at burst 102 ,  20.01475 was added
# at burst 102 ,  20.023 was added
# at burst 102 ,  20.032 was added
# burst 102 has  4 peaks
# new burst!
# at burst 103 ,  20.209 was added
# at burst 103 ,  20.219 was added
# at burst 103 ,  20.2275 was added
# at burst 103 ,  20.2365 was added
# burst 103 has  4 peaks
# new burst!
# at burst 104 ,  20.4135 was added
# at burst 104 ,  20.4235 was added
# at burst 104 ,  20.43325 was added
# burst 104 has  3 peaks
# new burst!
# at burst 105 ,  20.4425 was added
# burst 105 has  1 peaks
# new burst!
# at burst 106 ,  20.6185 was added
# at burst 106 ,  20.629 was added
# at burst 106 ,  20.638 was added
# at burst 106 ,  20.64725 was added
# burst 106 has  4 peaks
# new burst!
# at burst 107 ,  20.82425 was added
# at burst 107 ,  20.83425 was added
# at burst 107 ,  20.84275 was added
# at burst 107 ,  20.8515 was added
# burst 107 has  4 peaks
# new burst!
# at burst 108 ,  21.029 was added
# at burst 108 ,  21.03925 was added
# at burst 108 ,  21.048 was added
# burst 108 has  3 peaks
# new burst!
# at burst 109 ,  21.05775 was added
# burst 109 has  1 peaks
# new burst!
# at burst 110 ,  21.23375 was added
# at burst 110 ,  21.24425 was added
# at burst 110 ,  21.253 was added
# at burst 110 ,  21.2625 was added
# peak outside of last burst, BREAK!

# %%
maxtabALL = np.array(maxtabALL)
maxptimeALL = maxtabALL[:,0]
maxptimeALL = (np.multiply(maxptimeALL,0.00025) + time[0])
maxpeaksALL = maxtabALL[:,1]
maxpeaksALL = (np.subtract(maxpeaksALL,base))

# %%
burstpeaksY = []
for point in burstpeaks:
    burstpeaksY.append
# Out:
#   File "<ipython-input-27-d124a0742be5>", line 2
#     for point in burstpeaks
#                            ^
# SyntaxError: invalid syntax

# %%
bendy = []
for point in bend:
    bendy.append(base*0.5)

# %%
bstarty = []
for point in bstart:
    bstarty.append(base*0.5)

# %%
fig = plt.plot(time,data_shift, color="k")
#plt.plot(time,data_trans,color='b')
plt.plot(maxptimeALL,maxpeaksALL, marker = "^", color="g", linestyle= "None")
plt.plot(bstart, bstarty, marker = "v", color="y", linestyle= "None")
plt.plot(bend, bendy,marker = "v", color="m", linestyle= "None")
#plt.plot(minptime, minpeaks, marker ="v", color="m",  linestyle= "None")
plt.hlines(0,time[0],time[-1],colors='k')
plt.hlines((base*0.5),time[0],time[-1], colors='r')
DataCursor(fig)

# %%
plt.show(fig)

# %%
print data_trans[0:5]
print data_shift[0:5]
# Out:
# [ 0.0162657   0.01637714  0.01620614  0.01556582  0.01461065]
# [-0.03393484502707593, -0.033823404508265792, -0.03399440314027681, -0.034634719039026318, -0.035589891409805473]

# %%
x = time[0]

# %%
print x
# Out:
# 0.425

# %%
base
# Out:
# 0.050200543983550852

# %%
plt.hlines(0,time[0],time[-1])
